# %% [markdown]
# #Files, exceptional handling, logging and memory management

# %% [markdown]
# 1.  What is the difference between interpreted and compiled languages?
# -  **Interpreted languages** execute code line by line using an interpreter (e.g., Python, JavaScript), while **compiled languages** translate the entire code into machine language before execution using a compiler (e.g., C, C++).
# ***Key difference**:
#
# * **Interpreted** :- executes directly, slower but flexible.
# * **Compiled** :- executes after compilation, faster but less flexible.
# 2. What is exception handling in Python?
# - Exception handling in Python is the process of responding to runtime errors using `try`, `except`, `else`, and `finally` blocks. It allows the program to continue running or handle errors gracefully instead of crashing.
# 3. What is the purpose of the finally block in exception handling?
# - The purpose of the `finally` block in exception handling is to execute code regardless of whether an exception occurred or not. It is typically used for cleanup actions like closing files or releasing resources.
# 4.  What is logging in Python?
# - Logging in Python is the process of recording messages that describe the events or errors during the execution of a program. It helps in debugging, monitoring, and understanding the program's flow and behavior.
# 5. What is the significance of the __del__ method in Python?
# - The `__del__` method in Python is a special method called a destructor. It is automatically invoked when an object is about to be destroyed, and it is used to perform cleanup operations like releasing resources or closing files.
# 6.  What is the difference between import and from ... import in Python?
# - The **difference between `import` and `from ... import`** in Python is:
#
# * `import module` imports the entire module. You access functions or classes using `module.name`.
# * `from module import name` imports only specific parts (like a function or class) from the module, so you can use them directly without the module prefix.
# 7. How can you handle multiple exceptions in Python?
# - we can handle multiple exceptions in Python by:
#
# - Using **multiple `except` blocks** for different exception types.
# - Using a **single `except` block with a tuple** of exceptions.
# 8.  What is the purpose of the with statement when handling files in Python?
# - The purpose of the `with` statement when handling files in Python is to **automatically manage resources**, such as opening and closing files. It ensures that the file is properly closed after its suite finishes, even if an error occurs during processing.
# 9. What is the difference between multithreading and multiprocessing?
# - The difference between **multithreading** and **multiprocessing** is:
#
# * **Multithreading** uses multiple threads within a single process, sharing the same memory space. It is useful for I/O-bound tasks.
# * **Multiprocessing** uses multiple processes with separate memory, ideal for CPU-bound tasks as it can run on multiple cores.
# 10. What are the advantages of using logging in a program?
# - The advantages of using logging in a program are:
#
# - Helps in tracking events and errors during execution.
# - Useful for debugging and troubleshooting.
# - Allows saving logs to files for later analysis.
# - Provides different levels (info, warning, error, etc.) for better control.
# - Improves maintainability and monitoring of applications.
# 11. What is memory management in Python?
# - Memory management in Python is the process of **allocating and freeing memory** automatically during program execution. It includes features like:
#
# * Automatic garbage collection
# * Dynamic memory allocation
# * Reference counting
#
# This ensures efficient use of memory without manual intervention by the programmer.
# 12. What are the basic steps involved in exception handling in Python?
# - The basic steps involved in exception handling in Python are:
#
# - **Try block** - Write the code that may cause an exception.
# - **Except block** - Handle the exception if it occurs.
# - **Else block (optional)** - Run code if no exception occurs.
# - **Finally block (optional)** - Run code regardless of whether an exception occurred or not.
# 13. Why is memory management important in Python?
# - Memory management is important in Python because it:
#
# - Ensures efficient use of system memory.
# - Prevents memory leaks and program crashes.
# - Improves performance by freeing unused memory.
# - Supports scalability in large or long-running programs.
# 14. What is the role of try and except in exception handling?
# - The role of `try` and `except` in exception handling is:
#
# * **try**: Contains the code that may raise an exception.
# * **except**: Catches and handles the exception, preventing the program from crashing.
# 15. How does Python's garbage collection system work?
# - Python's garbage collection system works by **automatically reclaiming memory** occupied by objects that are no longer in use. It uses:
#
# - **Reference counting** - Tracks the number of references to an object; when it reaches zero, the object is deleted.
# - **Garbage collector** - Detects and cleans up **circular references** that reference counting alone can't handle.
# 16. What is the purpose of the else block in exception handling?
# - The purpose of the else block in exception handling is to execute code only if no exceptions occur in the try block. It is used for code that should run when the try block is successful.
# 17. What are the common logging levels in Python?
# - The common logging levels in Python are:
#
# - **DEBUG** - Detailed information, used for diagnosing problems.
# - **INFO** - General information about program execution.
# - **WARNING** - Indicates a potential problem.
# - **ERROR** - A more serious problem that caused a failure.
# - **CRITICAL** - A severe error indicating the program may not continue.
# 18. What is the difference between os.fork() and multiprocessing in Python?
# - The difference between `os.fork()` and `multiprocessing` in Python is:
#
# * **os.fork()**: Creates a child process by duplicating the current process. It is low-level, Unix-only, and requires manual management of processes.
# * **multiprocessing**: A high-level module that works on all platforms. It provides an easier and safer way to create and manage multiple processes using classes and functions.
# 19. What is the importance of closing a file in Python?
# - Closing a file in Python is important because it ensures that all the data is properly saved and system resources used by the file are released. It also helps prevent data corruption, loss, or access conflicts with other parts of the program or other programs.
# 20. What is the difference between file.read() and file.readline() in Python?
# - The difference between `file.read()` and `file.readline()` in Python is that `file.read()` reads the entire content of the file as a single string, while `file.readline()` reads only one line from the file at a time as a string.
# 21. What is the logging module in Python used for?
# - The logging module in Python is used for recording messages that help in tracking the execution of a program. It provides a flexible way to log information, warnings, errors, and debug messages, which can be useful for debugging, monitoring, and maintaining the application.
# 22. What is the os module in Python used for in file handling?
# - The os module in Python is used for interacting with the operating system, especially for tasks like file and directory handling. It allows you to create, delete, rename, and check the existence of files and directories, as well as navigate the file system.
# 23. What are the challenges associated with memory management in Python?
# - The challenges associated with memory management in Python include handling memory leaks caused by circular references, managing memory in long-running programs, and ensuring efficient use of memory in resource-intensive applications. Although Python has automatic garbage collection, improper coding practices can still lead to excessive memory usage or performance issues.
# 24. How do you raise an exception manually in Python?
# - You can raise an exception manually in Python using the `raise` statement followed by the exception type. This is useful when you want to trigger an error intentionally based on specific conditions in your code.
# 25. Why is it important to use multithreading in certain applications?
# - Using multithreading is important in certain applications because it allows multiple tasks to run concurrently within a single process, improving performance and responsiveness. It is especially useful for I/O-bound tasks like reading files, network operations, or user interface interactions, where waiting time can be utilized by other threads.
# ###PRACTICAL QUESTIONS
# 1. How can you open a file for writing in Python and write a string to it?

# %%
file = open("example.txt", "w")
file.write("Hello, this is a test.")
file.close()

# %% [markdown]
# 2. Write a Python program to read the contents of a file and print each line.

# %%
file = open("example.txt", "r")

for line in file:
    print(line.strip())

file.close()
# Out:
# Hello, this is a test.

# %% [markdown]
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
try:
    file = open("nonexistent.txt", "r")
    print(file.read())
    file.close()
except FileNotFoundError:
    print("The file does not exist.")
# Out:
# The file does not exist.

# %% [markdown]
# 4. Write a Python script that reads from one file and writes its content to another file.

# %%
try:
    with open("source.txt", "r") as source_file:
        content = source_file.read()

    with open("destination.txt", "w") as dest_file:
        dest_file.write(content)

    print("Content copied successfully.")

except FileNotFoundError:
    print("source.txt not found. Please make sure the file exists.")
except Exception as e:
    print("An error occurred:", e)
# Out:
# source.txt not found. Please make sure the file exists.

# %% [markdown]
# 5. How would you catch and handle division by zero error in Python?

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Cannot divide by zero.

# %% [markdown]
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

# %%
import logging

# Configure logging to write to a file
logging.basicConfig(filename='error.log', level=logging.ERROR, format='%(asctime)s - %(levelname)s - %(message)s')

try:
    result = 10 / 0
except ZeroDivisionError as e:
    logging.error("Division by zero occurred: %s", e)

print("Error logged to error.log")
# Out:
# ERROR:root:Division by zero occurred: division by zero
# Error logged to error.log

# %% [markdown]
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
import logging

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='%(levelname)s: %(message)s')

logging.info("This is an info message.")
logging.warning("This is a warning message.")
logging.error("This is an error message.")
# Out:
# WARNING:root:This is a warning message.
# ERROR:root:This is an error message.

# %% [markdown]
# 8. Write a program to handle a file opening error using exception handling.

# %%
try:
    file = open("data.txt", "r")
    content = file.read()
    file.close()
    print(content)
except FileNotFoundError:
    print("Error: The file 'data.txt' was not found.")
except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Error: The file 'data.txt' was not found.

# %% [markdown]
# 9. How can you read a file line by line and store its content in a list in Python?

# %%
with open("example.txt", "r") as file:
    lines = file.readlines()

print(lines)
# Out:
# ['Hello, this is a test.']

# %% [markdown]
# 10. How can you append data to an existing file in Python?

# %%
with open("example.txt", "a") as file:
    file.write("\nThis is new data being appended.")

# %% [markdown]
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

# %%
my_dict = {"name": "Gandhi", "age": 25}

try:
    print("City:", my_dict["city"])
except KeyError:
    print("Error: The key 'city' does not exist in the dictionary.")
# Out:
# Error: The key 'city' does not exist in the dictionary.

# %% [markdown]
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
    print("Result:", result)

    my_list = [1, 2, 3]
    print("List item:", my_list[5])

except ZeroDivisionError:
    print("Error: Cannot divide by zero.")

except ValueError:
    print("Error: Invalid input. Please enter a number.")

except IndexError:
    print("Error: List index out of range.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter a number: 1
# Result: 10.0
# Error: List index out of range.

# %% [markdown]
# 13. How would you check if a file exists before attempting to read it in Python?

# %%
import os

if os.path.exists("example.txt"):
    with open("example.txt", "r") as file:
        content = file.read()
        print(content)
else:
    print("The file does not exist.")
# Out:
# The file does not exist.

# %% [markdown]
# 14. Write a program that uses the logging module to log both informational and error messages.

# %%
import logging

# Configure logging
logging.basicConfig(filename='app.log', level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Log informational message
logging.info("Program started.")

try:
    x = 10 / 0
except ZeroDivisionError as e:
    logging.error("An error occurred: %s", e)

logging.info("Program ended.")
# Out:
# ERROR:root:An error occurred: division by zero

# %% [markdown]
# 15. Write a Python program that prints the content of a file and handles the case when the file is empty.

# %%
try:
    with open("example.txt", "r") as file:
        content = file.read()
        if content.strip() == "":
            print("The file is empty.")
        else:
            print("File content:")
            print(content)
except FileNotFoundError:
    print("The file 'example.txt' does not exist.")
# Out:
# The file 'example.txt' does not exist.

# %% [markdown]
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program.
# - **Step 1: Install memory_profiler**

# %%
pip install memory-profiler
# Out:
# Collecting memory-profiler
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory-profiler) (5.9.5)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory-profiler
# Successfully installed memory-profiler-0.61.0

# %% [markdown]
# - **Step 2: Save this program (e.g., as memory_example.py):**

# %%
from memory_profiler import profile

@profile
def demo():
    data = [i for i in range(10000)]
    print("Done")

demo()

# %% [markdown]
# - **Step 3: Run it using the command:**

# %%
python -m memory_profiler memory_example.py

# %% [markdown]
# 17. Write a Python program to create and write a list of numbers to a file, one number per line.

# %%
numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as file:
    for num in numbers:
        file.write(str(num) + "\n")

print("Numbers written to file successfully.")
# Out:
# Numbers written to file successfully.

# %% [markdown]
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %%
import logging
from logging.handlers import RotatingFileHandler

# Set up rotating logger
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.INFO)

# Create handler: rotates after 1MB, keeps 3 backup files
handler = RotatingFileHandler("app.log", maxBytes=1_000_000, backupCount=3)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

logger.addHandler(handler)

# Log sample messages
for i in range(10000):
    logger.info(f"Logging line number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:MyLogger:Logging line number 5000
# INFO:MyLogger:Logging line number 5001
# INFO:MyLogger:Logging line number 5002
# INFO:MyLogger:Logging line number 5003
# INFO:MyLogger:Logging line number 5004
# INFO:MyLogger:Logging line number 5005
# INFO:MyLogger:Logging line number 5006
# INFO:MyLogger:Logging line number 5007
# INFO:MyLogger:Logging line number 5008
# INFO:MyLogger:Logging line number 5009
# INFO:MyLogger:Logging line number 5010
# INFO:MyLogger:Logging line number 5011
# INFO:MyLogger:Logging line number 5012
# INFO:MyLogger:Logging line number 5013
# INFO:MyLogger:Logging line number 5014
# INFO:MyLogger:Logging line number 5015
# INFO:MyLogger:Logging line number 5016
# INFO:MyLogger:Logging line number 5017
# INFO:MyLogger:Logging line number 5018
# INFO:MyLogger:Logging line number 5019
# INFO:MyLogger:Logging line number 5020
# INFO:MyLogger:Logging line number 5021
# INFO:MyLogger:Logging line number 5022
# INFO:MyLogger:Logging line number 5023
# INFO:MyLogger:Logging line number 5024
# INFO:MyLogger:Logging line number 5025
# INFO:MyLogger:Logging line number 5026
# INFO:MyLogger:Logging line number 5027
# INFO:MyLogger:Logging line number 5028
# INFO:MyLogger:Logging line number 5029
# INFO:MyLogger:Logging line number 5030
# INFO:MyLogger:Logging line number 5031
# INFO:MyLogger:Logging line number 5032
# INFO:MyLogger:Logging line number 5033
# INFO:MyLogger:Logging line number 5034
# INFO:MyLogger:Logging line number 5035
# INFO:MyLogger:Logging line number 5036
# INFO:MyLogger:Logging line number 5037
# INFO:MyLogger:Logging line number 5038
# INFO:MyLogger:Logging line number 5039
# INFO:MyLogger:Logging line number 5040
# INFO:MyLogger:Logging line number 5041
# INFO:MyLogger:Logging line number 5042
# INFO:MyLogger:Logging line number 5043
# INFO:MyLogger:Logging line number 5044
# INFO:MyLogger:Logging line number 5045
# INFO:MyLogger:Logging line number 5046
# INFO:MyLogger:Logging line number 5047
# INFO:MyLogger:Logging line number 5048
# INFO:MyLogger:Logging line number 5049
# INFO:MyLogger:Logging line number 5050
# INFO:MyLogger:Logging line number 5051
# INFO:MyLogger:Logging line number 5052
# INFO:MyLogger:Logging line number 5053
# INFO:MyLogger:Logging line number 5054
# INFO:MyLogger:Logging line number 5055
# INFO:MyLogger:Logging line number 5056
# INFO:MyLogger:Logging line number 5057
# INFO:MyLogger:Logging line number 5058
# INFO:MyLogger:Logging line number 5059
# INFO:MyLogger:Logging line number 5060
# INFO:MyLogger:Logging line number 5061
# INFO:MyLogger:Logging line number 5062
# INFO:MyLogger:Logging line number 5063
# INFO:MyLogger:Logging line number 5064
# INFO:MyLogger:Logging line number 5065
# INFO:MyLogger:Logging line number 5066
# INFO:MyLogger:Logging line number 5067
# INFO:MyLogger:Logging line number 5068
# INFO:MyLogger:Logging line number 5069
# INFO:MyLogger:Logging line number 5070
# INFO:MyLogger:Logging line number 5071
# INFO:MyLogger:Logging line number 5072
# INFO:MyLogger:Logging line number 5073
# INFO:MyLogger:Logging line number 5074
# INFO:MyLogger:Logging line number 5075
# INFO:MyLogger:Logging line number 5076
# INFO:MyLogger:Logging line number 5077
# INFO:MyLogger:Logging line number 5078
# INFO:MyLogger:Logging line number 5079
# INFO:MyLogger:Logging line number 5080
# INFO:MyLogger:Logging line number 5081
# INFO:MyLogger:Logging line number 5082
# INFO:MyLogger:Logging line number 5083
# INFO:MyLogger:Logging line number 5084
# INFO:MyLogger:Logging line number 5085
# INFO:MyLogger:Logging line number 5086
# INFO:MyLogger:Logging line number 5087
# INFO:MyLogger:Logging line number 5088
# INFO:MyLogger:Logging line number 5089
# INFO:MyLogger:Logging line number 5090
# INFO:MyLogger:Logging line number 5091
# INFO:MyLogger:Logging line number 5092
# INFO:MyLogger:Logging line number 5093
# INFO:MyLogger:Logging line number 5094
# INFO:MyLogger:Logging line number 5095
# INFO:MyLogger:Logging line number 5096
# INFO:MyLogger:Logging line number 5097
# INFO:MyLogger:Logging line number 5098
# INFO:MyLogger:Logging line number 5099
# INFO:MyLogger:Logging line number 5100
# INFO:MyLogger:Logging line number 5101
# INFO:MyLogger:Logging line number 5102
# INFO:MyLogger:Logging line number 5103
# INFO:MyLogger:Logging line number 5104
# INFO:MyLogger:Logging line number 5105
# INFO:MyLogger:Logging line number 5106
# INFO:MyLogger:Logging line number 5107
# INFO:MyLogger:Logging line number 5108
# INFO:MyLogger:Logging line number 5109
# INFO:MyLogger:Logging line number 5110
# INFO:MyLogger:Logging line number 5111
# INFO:MyLogger:Logging line number 5112
# INFO:MyLogger:Logging line number 5113
# INFO:MyLogger:Logging line number 5114
# INFO:MyLogger:Logging line number 5115
# INFO:MyLogger:Logging line number 5116
# INFO:MyLogger:Logging line number 5117
# INFO:MyLogger:Logging line number 5118
# INFO:MyLogger:Logging line number 5119
# INFO:MyLogger:Logging line number 5120
# INFO:MyLogger:Logging line number 5121
# INFO:MyLogger:Logging line number 5122
# INFO:MyLogger:Logging line number 5123
# INFO:MyLogger:Logging line number 5124
# INFO:MyLogger:Logging line number 5125
# INFO:MyLogger:Logging line number 5126
# INFO:MyLogger:Logging line number 5127
# INFO:MyLogger:Logging line number 5128
# INFO:MyLogger:Logging line number 5129
# INFO:MyLogger:Logging line number 5130
# INFO:MyLogger:Logging line number 5131
# INFO:MyLogger:Logging line number 5132
# INFO:MyLogger:Logging line number 5133
# INFO:MyLogger:Logging line number 5134
# INFO:MyLogger:Logging line number 5135
# INFO:MyLogger:Logging line number 5136
# INFO:MyLogger:Logging line number 5137
# INFO:MyLogger:Logging line number 5138
# INFO:MyLogger:Logging line number 5139
# INFO:MyLogger:Logging line number 5140
# INFO:MyLogger:Logging line number 5141
# INFO:MyLogger:Logging line number 5142
# INFO:MyLogger:Logging line number 5143
# INFO:MyLogger:Logging line number 5144
# INFO:MyLogger:Logging line number 5145
# INFO:MyLogger:Logging line number 5146
# INFO:MyLogger:Logging line number 5147
# INFO:MyLogger:Logging line number 5148
# INFO:MyLogger:Logging line number 5149
# INFO:MyLogger:Logging line number 5150
# INFO:MyLogger:Logging line number 5151
# INFO:MyLogger:Logging line number 5152
# INFO:MyLogger:Logging line number 5153
# INFO:MyLogger:Logging line number 5154
# INFO:MyLogger:Logging line number 5155
# INFO:MyLogger:Logging line number 5156
# INFO:MyLogger:Logging line number 5157
# INFO:MyLogger:Logging line number 5158
# INFO:MyLogger:Logging line number 5159
# INFO:MyLogger:Logging line number 5160
# INFO:MyLogger:Logging line number 5161
# INFO:MyLogger:Logging line number 5162
# INFO:MyLogger:Logging line number 5163
# INFO:MyLogger:Logging line number 5164
# INFO:MyLogger:Logging line number 5165
# INFO:MyLogger:Logging line number 5166
# INFO:MyLogger:Logging line number 5167
# INFO:MyLogger:Logging line number 5168
# INFO:MyLogger:Logging line number 5169
# INFO:MyLogger:Logging line number 5170
# INFO:MyLogger:Logging line number 5171
# INFO:MyLogger:Logging line number 5172
# INFO:MyLogger:Logging line number 5173
# INFO:MyLogger:Logging line number 5174
# INFO:MyLogger:Logging line number 5175
# INFO:MyLogger:Logging line number 5176
# INFO:MyLogger:Logging line number 5177
# INFO:MyLogger:Logging line number 5178
# INFO:MyLogger:Logging line number 5179
# INFO:MyLogger:Logging line number 5180
# INFO:MyLogger:Logging line number 5181
# INFO:MyLogger:Logging line number 5182
# INFO:MyLogger:Logging line number 5183
# INFO:MyLogger:Logging line number 5184
# INFO:MyLogger:Logging line number 5185
# INFO:MyLogger:Logging line number 5186
# INFO:MyLogger:Logging line number 5187
# INFO:MyLogger:Logging line number 5188
# INFO:MyLogger:Logging line number 5189
# INFO:MyLogger:Logging line number 5190
# INFO:MyLogger:Logging line number 5191
# INFO:MyLogger:Logging line number 5192
# INFO:MyLogger:Logging line number 5193
# INFO:MyLogger:Logging line number 5194
# INFO:MyLogger:Logging line number 5195
# INFO:MyLogger:Logging line number 5196
# INFO:MyLogger:Logging line number 5197
# INFO:MyLogger:Logging line number 5198
# INFO:MyLogger:Logging line number 5199
# INFO:MyLogger:Logging line number 5200
# INFO:MyLogger:Logging line number 5201
# INFO:MyLogger:Logging line number 5202
# INFO:MyLogger:Logging line number 5203
# INFO:MyLogger:Logging line number 5204
# INFO:MyLogger:Logging line number 5205
# INFO:MyLogger:Logging line number 5206
# INFO:MyLogger:Logging line number 5207
# INFO:MyLogger:Logging line number 5208
# INFO:MyLogger:Logging line number 5209
# INFO:MyLogger:Logging line number 5210
# INFO:MyLogger:Logging line number 5211
# INFO:MyLogger:Logging line number 5212
# INFO:MyLogger:Logging line number 5213
# INFO:MyLogger:Logging line number 5214
# INFO:MyLogger:Logging line number 5215
# INFO:MyLogger:Logging line number 5216
# INFO:MyLogger:Logging line number 5217
# INFO:MyLogger:Logging line number 5218
# INFO:MyLogger:Logging line number 5219
# INFO:MyLogger:Logging line number 5220
# INFO:MyLogger:Logging line number 5221
# INFO:MyLogger:Logging line number 5222
# INFO:MyLogger:Logging line number 5223
# INFO:MyLogger:Logging line number 5224
# INFO:MyLogger:Logging line number 5225
# INFO:MyLogger:Logging line number 5226
# INFO:MyLogger:Logging line number 5227
# INFO:MyLogger:Logging line number 5228
# INFO:MyLogger:Logging line number 5229
# INFO:MyLogger:Logging line number 5230
# INFO:MyLogger:Logging line number 5231
# INFO:MyLogger:Logging line number 5232
# INFO:MyLogger:Logging line number 5233
# INFO:MyLogger:Logging line number 5234
# INFO:MyLogger:Logging line number 5235
# INFO:MyLogger:Logging line number 5236
# INFO:MyLogger:Logging line number 5237
# INFO:MyLogger:Logging line number 5238
# INFO:MyLogger:Logging line number 5239
# INFO:MyLogger:Logging line number 5240
# INFO:MyLogger:Logging line number 5241
# INFO:MyLogger:Logging line number 5242
# INFO:MyLogger:Logging line number 5243
# INFO:MyLogger:Logging line number 5244
# INFO:MyLogger:Logging line number 5245
# INFO:MyLogger:Logging line number 5246
# INFO:MyLogger:Logging line number 5247
# INFO:MyLogger:Logging line number 5248
# INFO:MyLogger:Logging line number 5249
# INFO:MyLogger:Logging line number 5250
# INFO:MyLogger:Logging line number 5251
# INFO:MyLogger:Logging line number 5252
# INFO:MyLogger:Logging line number 5253
# INFO:MyLogger:Logging line number 5254
# INFO:MyLogger:Logging line number 5255
# INFO:MyLogger:Logging line number 5256
# INFO:MyLogger:Logging line number 5257
# INFO:MyLogger:Logging line number 5258
# INFO:MyLogger:Logging line number 5259
# INFO:MyLogger:Logging line number 5260
# INFO:MyLogger:Logging line number 5261
# INFO:MyLogger:Logging line number 5262
# INFO:MyLogger:Logging line number 5263
# INFO:MyLogger:Logging line number 5264
# INFO:MyLogger:Logging line number 5265
# INFO:MyLogger:Logging line number 5266
# INFO:MyLogger:Logging line number 5267
# INFO:MyLogger:Logging line number 5268
# INFO:MyLogger:Logging line number 5269
# INFO:MyLogger:Logging line number 5270
# INFO:MyLogger:Logging line number 5271
# INFO:MyLogger:Logging line number 5272
# INFO:MyLogger:Logging line number 5273
# INFO:MyLogger:Logging line number 5274
# INFO:MyLogger:Logging line number 5275
# INFO:MyLogger:Logging line number 5276
# INFO:MyLogger:Logging line number 5277
# INFO:MyLogger:Logging line number 5278
# INFO:MyLogger:Logging line number 5279
# INFO:MyLogger:Logging line number 5280
# INFO:MyLogger:Logging line number 5281
# INFO:MyLogger:Logging line number 5282
# INFO:MyLogger:Logging line number 5283
# INFO:MyLogger:Logging line number 5284
# INFO:MyLogger:Logging line number 5285
# INFO:MyLogger:Logging line number 5286
# INFO:MyLogger:Logging line number 5287
# INFO:MyLogger:Logging line number 5288
# INFO:MyLogger:Logging line number 5289
# INFO:MyLogger:Logging line number 5290
# INFO:MyLogger:Logging line number 5291
# INFO:MyLogger:Logging line number 5292
# INFO:MyLogger:Logging line number 5293
# INFO:MyLogger:Logging line number 5294
# INFO:MyLogger:Logging line number 5295
# INFO:MyLogger:Logging line number 5296
# INFO:MyLogger:Logging line number 5297
# INFO:MyLogger:Logging line number 5298
# INFO:MyLogger:Logging line number 5299
# INFO:MyLogger:Logging line number 5300
# INFO:MyLogger:Logging line number 5301
# INFO:MyLogger:Logging line number 5302
# INFO:MyLogger:Logging line number 5303
# INFO:MyLogger:Logging line number 5304
# INFO:MyLogger:Logging line number 5305
# INFO:MyLogger:Logging line number 5306
# INFO:MyLogger:Logging line number 5307
# INFO:MyLogger:Logging line number 5308
# INFO:MyLogger:Logging line number 5309
# INFO:MyLogger:Logging line number 5310
# INFO:MyLogger:Logging line number 5311
# INFO:MyLogger:Logging line number 5312
# INFO:MyLogger:Logging line number 5313
# INFO:MyLogger:Logging line number 5314
# INFO:MyLogger:Logging line number 5315
# INFO:MyLogger:Logging line number 5316
# INFO:MyLogger:Logging line number 5317
# INFO:MyLogger:Logging line number 5318
# INFO:MyLogger:Logging line number 5319
# INFO:MyLogger:Logging line number 5320
# INFO:MyLogger:Logging line number 5321
# INFO:MyLogger:Logging line number 5322
# INFO:MyLogger:Logging line number 5323
# INFO:MyLogger:Logging line number 5324
# INFO:MyLogger:Logging line number 5325
# INFO:MyLogger:Logging line number 5326
# INFO:MyLogger:Logging line number 5327
# INFO:MyLogger:Logging line number 5328
# INFO:MyLogger:Logging line number 5329
# INFO:MyLogger:Logging line number 5330
# INFO:MyLogger:Logging line number 5331
# INFO:MyLogger:Logging line number 5332
# INFO:MyLogger:Logging line number 5333
# INFO:MyLogger:Logging line number 5334
# INFO:MyLogger:Logging line number 5335
# INFO:MyLogger:Logging line number 5336
# INFO:MyLogger:Logging line number 5337
# INFO:MyLogger:Logging line number 5338
# INFO:MyLogger:Logging line number 5339
# INFO:MyLogger:Logging line number 5340
# INFO:MyLogger:Logging line number 5341
# INFO:MyLogger:Logging line number 5342
# INFO:MyLogger:Logging line number 5343
# INFO:MyLogger:Logging line number 5344
# INFO:MyLogger:Logging line number 5345
# INFO:MyLogger:Logging line number 5346
# INFO:MyLogger:Logging line number 5347
# INFO:MyLogger:Logging line number 5348
# INFO:MyLogger:Logging line number 5349
# INFO:MyLogger:Logging line number 5350
# INFO:MyLogger:Logging line number 5351
# INFO:MyLogger:Logging line number 5352
# INFO:MyLogger:Logging line number 5353
# INFO:MyLogger:Logging line number 5354
# INFO:MyLogger:Logging line number 5355
# INFO:MyLogger:Logging line number 5356
# INFO:MyLogger:Logging line number 5357
# INFO:MyLogger:Logging line number 5358
# INFO:MyLogger:Logging line number 5359
# INFO:MyLogger:Logging line number 5360
# INFO:MyLogger:Logging line number 5361
# INFO:MyLogger:Logging line number 5362
# INFO:MyLogger:Logging line number 5363
# INFO:MyLogger:Logging line number 5364
# INFO:MyLogger:Logging line number 5365
# INFO:MyLogger:Logging line number 5366
# INFO:MyLogger:Logging line number 5367
# INFO:MyLogger:Logging line number 5368
# INFO:MyLogger:Logging line number 5369
# INFO:MyLogger:Logging line number 5370
# INFO:MyLogger:Logging line number 5371
# INFO:MyLogger:Logging line number 5372
# INFO:MyLogger:Logging line number 5373
# INFO:MyLogger:Logging line number 5374
# INFO:MyLogger:Logging line number 5375
# INFO:MyLogger:Logging line number 5376
# INFO:MyLogger:Logging line number 5377
# INFO:MyLogger:Logging line number 5378
# INFO:MyLogger:Logging line number 5379
# INFO:MyLogger:Logging line number 5380
# INFO:MyLogger:Logging line number 5381
# INFO:MyLogger:Logging line number 5382
# INFO:MyLogger:Logging line number 5383
# INFO:MyLogger:Logging line number 5384
# INFO:MyLogger:Logging line number 5385
# INFO:MyLogger:Logging line number 5386
# INFO:MyLogger:Logging line number 5387
# INFO:MyLogger:Logging line number 5388
# INFO:MyLogger:Logging line number 5389
# INFO:MyLogger:Logging line number 5390
# INFO:MyLogger:Logging line number 5391
# INFO:MyLogger:Logging line number 5392
# INFO:MyLogger:Logging line number 5393
# INFO:MyLogger:Logging line number 5394
# INFO:MyLogger:Logging line number 5395
# INFO:MyLogger:Logging line number 5396
# INFO:MyLogger:Logging line number 5397
# INFO:MyLogger:Logging line number 5398
# INFO:MyLogger:Logging line number 5399
# INFO:MyLogger:Logging line number 5400
# INFO:MyLogger:Logging line number 5401
# INFO:MyLogger:Logging line number 5402
# INFO:MyLogger:Logging line number 5403
# INFO:MyLogger:Logging line number 5404
# INFO:MyLogger:Logging line number 5405
# INFO:MyLogger:Logging line number 5406
# INFO:MyLogger:Logging line number 5407
# INFO:MyLogger:Logging line number 5408
# INFO:MyLogger:Logging line number 5409
# INFO:MyLogger:Logging line number 5410
# INFO:MyLogger:Logging line number 5411
# INFO:MyLogger:Logging line number 5412
# INFO:MyLogger:Logging line number 5413
# INFO:MyLogger:Logging line number 5414
# INFO:MyLogger:Logging line number 5415
# INFO:MyLogger:Logging line number 5416
# INFO:MyLogger:Logging line number 5417
# INFO:MyLogger:Logging line number 5418
# INFO:MyLogger:Logging line number 5419
# INFO:MyLogger:Logging line number 5420
# INFO:MyLogger:Logging line number 5421
# INFO:MyLogger:Logging line number 5422
# INFO:MyLogger:Logging line number 5423
# INFO:MyLogger:Logging line number 5424
# INFO:MyLogger:Logging line number 5425
# INFO:MyLogger:Logging line number 5426
# INFO:MyLogger:Logging line number 5427
# INFO:MyLogger:Logging line number 5428
# INFO:MyLogger:Logging line number 5429
# INFO:MyLogger:Logging line number 5430
# INFO:MyLogger:Logging line number 5431
# INFO:MyLogger:Logging line number 5432
# INFO:MyLogger:Logging line number 5433
# INFO:MyLogger:Logging line number 5434
# INFO:MyLogger:Logging line number 5435
# INFO:MyLogger:Logging line number 5436
# INFO:MyLogger:Logging line number 5437
# INFO:MyLogger:Logging line number 5438
# INFO:MyLogger:Logging line number 5439
# INFO:MyLogger:Logging line number 5440
# INFO:MyLogger:Logging line number 5441
# INFO:MyLogger:Logging line number 5442
# INFO:MyLogger:Logging line number 5443
# INFO:MyLogger:Logging line number 5444
# INFO:MyLogger:Logging line number 5445
# INFO:MyLogger:Logging line number 5446
# INFO:MyLogger:Logging line number 5447
# INFO:MyLogger:Logging line number 5448
# INFO:MyLogger:Logging line number 5449
# INFO:MyLogger:Logging line number 5450
# INFO:MyLogger:Logging line number 5451
# INFO:MyLogger:Logging line number 5452
# INFO:MyLogger:Logging line number 5453
# INFO:MyLogger:Logging line number 5454
# INFO:MyLogger:Logging line number 5455
# INFO:MyLogger:Logging line number 5456
# INFO:MyLogger:Logging line number 5457
# INFO:MyLogger:Logging line number 5458
# INFO:MyLogger:Logging line number 5459
# INFO:MyLogger:Logging line number 5460
# INFO:MyLogger:Logging line number 5461
# INFO:MyLogger:Logging line number 5462
# INFO:MyLogger:Logging line number 5463
# INFO:MyLogger:Logging line number 5464
# INFO:MyLogger:Logging line number 5465
# INFO:MyLogger:Logging line number 5466
# INFO:MyLogger:Logging line number 5467
# INFO:MyLogger:Logging line number 5468
# INFO:MyLogger:Logging line number 5469
# INFO:MyLogger:Logging line number 5470
# INFO:MyLogger:Logging line number 5471
# INFO:MyLogger:Logging line number 5472
# INFO:MyLogger:Logging line number 5473
# INFO:MyLogger:Logging line number 5474
# INFO:MyLogger:Logging line number 5475
# INFO:MyLogger:Logging line number 5476
# INFO:MyLogger:Logging line number 5477
# INFO:MyLogger:Logging line number 5478
# INFO:MyLogger:Logging line number 5479
# INFO:MyLogger:Logging line number 5480
# INFO:MyLogger:Logging line number 5481
# INFO:MyLogger:Logging line number 5482
# INFO:MyLogger:Logging line number 5483
# INFO:MyLogger:Logging line number 5484
# INFO:MyLogger:Logging line number 5485
# INFO:MyLogger:Logging line number 5486
# INFO:MyLogger:Logging line number 5487
# INFO:MyLogger:Logging line number 5488
# INFO:MyLogger:Logging line number 5489
# INFO:MyLogger:Logging line number 5490
# INFO:MyLogger:Logging line number 5491
# INFO:MyLogger:Logging line number 5492
# INFO:MyLogger:Logging line number 5493
# INFO:MyLogger:Logging line number 5494
# INFO:MyLogger:Logging line number 5495
# INFO:MyLogger:Logging line number 5496
# INFO:MyLogger:Logging line number 5497
# INFO:MyLogger:Logging line number 5498
# INFO:MyLogger:Logging line number 5499
# INFO:MyLogger:Logging line number 5500
# INFO:MyLogger:Logging line number 5501
# INFO:MyLogger:Logging line number 5502
# INFO:MyLogger:Logging line number 5503
# INFO:MyLogger:Logging line number 5504
# INFO:MyLogger:Logging line number 5505
# INFO:MyLogger:Logging line number 5506
# INFO:MyLogger:Logging line number 5507
# INFO:MyLogger:Logging line number 5508
# INFO:MyLogger:Logging line number 5509
# INFO:MyLogger:Logging line number 5510
# INFO:MyLogger:Logging line number 5511
# INFO:MyLogger:Logging line number 5512
# INFO:MyLogger:Logging line number 5513
# INFO:MyLogger:Logging line number 5514
# INFO:MyLogger:Logging line number 5515
# INFO:MyLogger:Logging line number 5516
# INFO:MyLogger:Logging line number 5517
# INFO:MyLogger:Logging line number 5518
# INFO:MyLogger:Logging line number 5519
# INFO:MyLogger:Logging line number 5520
# INFO:MyLogger:Logging line number 5521
# INFO:MyLogger:Logging line number 5522
# INFO:MyLogger:Logging line number 5523
# INFO:MyLogger:Logging line number 5524
# INFO:MyLogger:Logging line number 5525
# INFO:MyLogger:Logging line number 5526
# INFO:MyLogger:Logging line number 5527
# INFO:MyLogger:Logging line number 5528
# INFO:MyLogger:Logging line number 5529
# INFO:MyLogger:Logging line number 5530
# INFO:MyLogger:Logging line number 5531
# INFO:MyLogger:Logging line number 5532
# INFO:MyLogger:Logging line number 5533
# INFO:MyLogger:Logging line number 5534
# INFO:MyLogger:Logging line number 5535
# INFO:MyLogger:Logging line number 5536
# INFO:MyLogger:Logging line number 5537
# INFO:MyLogger:Logging line number 5538
# INFO:MyLogger:Logging line number 5539
# INFO:MyLogger:Logging line number 5540
# INFO:MyLogger:Logging line number 5541
# INFO:MyLogger:Logging line number 5542
# INFO:MyLogger:Logging line number 5543
# INFO:MyLogger:Logging line number 5544
# INFO:MyLogger:Logging line number 5545
# INFO:MyLogger:Logging line number 5546
# INFO:MyLogger:Logging line number 5547
# INFO:MyLogger:Logging line number 5548
# INFO:MyLogger:Logging line number 5549
# INFO:MyLogger:Logging line number 5550
# INFO:MyLogger:Logging line number 5551
# INFO:MyLogger:Logging line number 5552
# INFO:MyLogger:Logging line number 5553
# INFO:MyLogger:Logging line number 5554
# INFO:MyLogger:Logging line number 5555
# INFO:MyLogger:Logging line number 5556
# INFO:MyLogger:Logging line number 5557
# INFO:MyLogger:Logging line number 5558
# INFO:MyLogger:Logging line number 5559
# INFO:MyLogger:Logging line number 5560
# INFO:MyLogger:Logging line number 5561
# INFO:MyLogger:Logging line number 5562
# INFO:MyLogger:Logging line number 5563
# INFO:MyLogger:Logging line number 5564
# INFO:MyLogger:Logging line number 5565
# INFO:MyLogger:Logging line number 5566
# INFO:MyLogger:Logging line number 5567
# INFO:MyLogger:Logging line number 5568
# INFO:MyLogger:Logging line number 5569
# INFO:MyLogger:Logging line number 5570
# INFO:MyLogger:Logging line number 5571
# INFO:MyLogger:Logging line number 5572
# INFO:MyLogger:Logging line number 5573
# INFO:MyLogger:Logging line number 5574
# INFO:MyLogger:Logging line number 5575
# INFO:MyLogger:Logging line number 5576
# INFO:MyLogger:Logging line number 5577
# INFO:MyLogger:Logging line number 5578
# INFO:MyLogger:Logging line number 5579
# INFO:MyLogger:Logging line number 5580
# INFO:MyLogger:Logging line number 5581
# INFO:MyLogger:Logging line number 5582
# INFO:MyLogger:Logging line number 5583
# INFO:MyLogger:Logging line number 5584
# INFO:MyLogger:Logging line number 5585
# INFO:MyLogger:Logging line number 5586
# INFO:MyLogger:Logging line number 5587
# INFO:MyLogger:Logging line number 5588
# INFO:MyLogger:Logging line number 5589
# INFO:MyLogger:Logging line number 5590
# INFO:MyLogger:Logging line number 5591
# INFO:MyLogger:Logging line number 5592
# INFO:MyLogger:Logging line number 5593
# INFO:MyLogger:Logging line number 5594
# INFO:MyLogger:Logging line number 5595
# INFO:MyLogger:Logging line number 5596
# INFO:MyLogger:Logging line number 5597
# INFO:MyLogger:Logging line number 5598
# INFO:MyLogger:Logging line number 5599
# INFO:MyLogger:Logging line number 5600
# INFO:MyLogger:Logging line number 5601
# INFO:MyLogger:Logging line number 5602
# INFO:MyLogger:Logging line number 5603
# INFO:MyLogger:Logging line number 5604
# INFO:MyLogger:Logging line number 5605
# INFO:MyLogger:Logging line number 5606
# INFO:MyLogger:Logging line number 5607
# INFO:MyLogger:Logging line number 5608
# INFO:MyLogger:Logging line number 5609
# INFO:MyLogger:Logging line number 5610
# INFO:MyLogger:Logging line number 5611
# INFO:MyLogger:Logging line number 5612
# INFO:MyLogger:Logging line number 5613
# INFO:MyLogger:Logging line number 5614
# INFO:MyLogger:Logging line number 5615
# INFO:MyLogger:Logging line number 5616
# INFO:MyLogger:Logging line number 5617
# INFO:MyLogger:Logging line number 5618
# INFO:MyLogger:Logging line number 5619
# INFO:MyLogger:Logging line number 5620
# INFO:MyLogger:Logging line number 5621
# INFO:MyLogger:Logging line number 5622
# INFO:MyLogger:Logging line number 5623
# INFO:MyLogger:Logging line number 5624
# INFO:MyLogger:Logging line number 5625
# INFO:MyLogger:Logging line number 5626
# INFO:MyLogger:Logging line number 5627
# INFO:MyLogger:Logging line number 5628
# INFO:MyLogger:Logging line number 5629
# INFO:MyLogger:Logging line number 5630
# INFO:MyLogger:Logging line number 5631
# INFO:MyLogger:Logging line number 5632
# INFO:MyLogger:Logging line number 5633
# INFO:MyLogger:Logging line number 5634
# INFO:MyLogger:Logging line number 5635
# INFO:MyLogger:Logging line number 5636
# INFO:MyLogger:Logging line number 5637
# INFO:MyLogger:Logging line number 5638
# INFO:MyLogger:Logging line number 5639
# INFO:MyLogger:Logging line number 5640
# INFO:MyLogger:Logging line number 5641
# INFO:MyLogger:Logging line number 5642
# INFO:MyLogger:Logging line number 5643
# INFO:MyLogger:Logging line number 5644
# INFO:MyLogger:Logging line number 5645
# INFO:MyLogger:Logging line number 5646
# INFO:MyLogger:Logging line number 5647
# INFO:MyLogger:Logging line number 5648
# INFO:MyLogger:Logging line number 5649
# INFO:MyLogger:Logging line number 5650
# INFO:MyLogger:Logging line number 5651
# INFO:MyLogger:Logging line number 5652
# INFO:MyLogger:Logging line number 5653
# INFO:MyLogger:Logging line number 5654
# INFO:MyLogger:Logging line number 5655
# INFO:MyLogger:Logging line number 5656
# INFO:MyLogger:Logging line number 5657
# INFO:MyLogger:Logging line number 5658
# INFO:MyLogger:Logging line number 5659
# INFO:MyLogger:Logging line number 5660
# INFO:MyLogger:Logging line number 5661
# INFO:MyLogger:Logging line number 5662
# INFO:MyLogger:Logging line number 5663
# INFO:MyLogger:Logging line number 5664
# INFO:MyLogger:Logging line number 5665
# INFO:MyLogger:Logging line number 5666
# INFO:MyLogger:Logging line number 5667
# INFO:MyLogger:Logging line number 5668
# INFO:MyLogger:Logging line number 5669
# INFO:MyLogger:Logging line number 5670
# INFO:MyLogger:Logging line number 5671
# INFO:MyLogger:Logging line number 5672
# INFO:MyLogger:Logging line number 5673
# INFO:MyLogger:Logging line number 5674
# INFO:MyLogger:Logging line number 5675
# INFO:MyLogger:Logging line number 5676
# INFO:MyLogger:Logging line number 5677
# INFO:MyLogger:Logging line number 5678
# INFO:MyLogger:Logging line number 5679
# INFO:MyLogger:Logging line number 5680
# INFO:MyLogger:Logging line number 5681
# INFO:MyLogger:Logging line number 5682
# INFO:MyLogger:Logging line number 5683
# INFO:MyLogger:Logging line number 5684
# INFO:MyLogger:Logging line number 5685
# INFO:MyLogger:Logging line number 5686
# INFO:MyLogger:Logging line number 5687
# INFO:MyLogger:Logging line number 5688
# INFO:MyLogger:Logging line number 5689
# INFO:MyLogger:Logging line number 5690
# INFO:MyLogger:Logging line number 5691
# INFO:MyLogger:Logging line number 5692
# INFO:MyLogger:Logging line number 5693
# INFO:MyLogger:Logging line number 5694
# INFO:MyLogger:Logging line number 5695
# INFO:MyLogger:Logging line number 5696
# INFO:MyLogger:Logging line number 5697
# INFO:MyLogger:Logging line number 5698
# INFO:MyLogger:Logging line number 5699
# INFO:MyLogger:Logging line number 5700
# INFO:MyLogger:Logging line number 5701
# INFO:MyLogger:Logging line number 5702
# INFO:MyLogger:Logging line number 5703
# INFO:MyLogger:Logging line number 5704
# INFO:MyLogger:Logging line number 5705
# INFO:MyLogger:Logging line number 5706
# INFO:MyLogger:Logging line number 5707
# INFO:MyLogger:Logging line number 5708
# INFO:MyLogger:Logging line number 5709
# INFO:MyLogger:Logging line number 5710
# INFO:MyLogger:Logging line number 5711
# INFO:MyLogger:Logging line number 5712
# INFO:MyLogger:Logging line number 5713
# INFO:MyLogger:Logging line number 5714
# INFO:MyLogger:Logging line number 5715
# INFO:MyLogger:Logging line number 5716
# INFO:MyLogger:Logging line number 5717
# INFO:MyLogger:Logging line number 5718
# INFO:MyLogger:Logging line number 5719
# INFO:MyLogger:Logging line number 5720
# INFO:MyLogger:Logging line number 5721
# INFO:MyLogger:Logging line number 5722
# INFO:MyLogger:Logging line number 5723
# INFO:MyLogger:Logging line number 5724
# INFO:MyLogger:Logging line number 5725
# INFO:MyLogger:Logging line number 5726
# INFO:MyLogger:Logging line number 5727
# INFO:MyLogger:Logging line number 5728
# INFO:MyLogger:Logging line number 5729
# INFO:MyLogger:Logging line number 5730
# INFO:MyLogger:Logging line number 5731
# INFO:MyLogger:Logging line number 5732
# INFO:MyLogger:Logging line number 5733
# INFO:MyLogger:Logging line number 5734
# INFO:MyLogger:Logging line number 5735
# INFO:MyLogger:Logging line number 5736
# INFO:MyLogger:Logging line number 5737
# INFO:MyLogger:Logging line number 5738
# INFO:MyLogger:Logging line number 5739
# INFO:MyLogger:Logging line number 5740
# INFO:MyLogger:Logging line number 5741
# INFO:MyLogger:Logging line number 5742
# INFO:MyLogger:Logging line number 5743
# INFO:MyLogger:Logging line number 5744
# INFO:MyLogger:Logging line number 5745
# INFO:MyLogger:Logging line number 5746
# INFO:MyLogger:Logging line number 5747
# INFO:MyLogger:Logging line number 5748
# INFO:MyLogger:Logging line number 5749
# INFO:MyLogger:Logging line number 5750
# INFO:MyLogger:Logging line number 5751
# INFO:MyLogger:Logging line number 5752
# INFO:MyLogger:Logging line number 5753
# INFO:MyLogger:Logging line number 5754
# INFO:MyLogger:Logging line number 5755
# INFO:MyLogger:Logging line number 5756
# INFO:MyLogger:Logging line number 5757
# INFO:MyLogger:Logging line number 5758
# INFO:MyLogger:Logging line number 5759
# INFO:MyLogger:Logging line number 5760
# INFO:MyLogger:Logging line number 5761
# INFO:MyLogger:Logging line number 5762
# INFO:MyLogger:Logging line number 5763
# INFO:MyLogger:Logging line number 5764
# INFO:MyLogger:Logging line number 5765
# INFO:MyLogger:Logging line number 5766
# INFO:MyLogger:Logging line number 5767
# INFO:MyLogger:Logging line number 5768
# INFO:MyLogger:Logging line number 5769
# INFO:MyLogger:Logging line number 5770
# INFO:MyLogger:Logging line number 5771
# INFO:MyLogger:Logging line number 5772
# INFO:MyLogger:Logging line number 5773
# INFO:MyLogger:Logging line number 5774
# INFO:MyLogger:Logging line number 5775
# INFO:MyLogger:Logging line number 5776
# INFO:MyLogger:Logging line number 5777
# INFO:MyLogger:Logging line number 5778
# INFO:MyLogger:Logging line number 5779
# INFO:MyLogger:Logging line number 5780
# INFO:MyLogger:Logging line number 5781
# INFO:MyLogger:Logging line number 5782
# INFO:MyLogger:Logging line number 5783
# INFO:MyLogger:Logging line number 5784
# INFO:MyLogger:Logging line number 5785
# INFO:MyLogger:Logging line number 5786
# INFO:MyLogger:Logging line number 5787
# INFO:MyLogger:Logging line number 5788
# INFO:MyLogger:Logging line number 5789
# INFO:MyLogger:Logging line number 5790
# INFO:MyLogger:Logging line number 5791
# INFO:MyLogger:Logging line number 5792
# INFO:MyLogger:Logging line number 5793
# INFO:MyLogger:Logging line number 5794
# INFO:MyLogger:Logging line number 5795
# INFO:MyLogger:Logging line number 5796
# INFO:MyLogger:Logging line number 5797
# INFO:MyLogger:Logging line number 5798
# INFO:MyLogger:Logging line number 5799
# INFO:MyLogger:Logging line number 5800
# INFO:MyLogger:Logging line number 5801
# INFO:MyLogger:Logging line number 5802
# INFO:MyLogger:Logging line number 5803
# INFO:MyLogger:Logging line number 5804
# INFO:MyLogger:Logging line number 5805
# INFO:MyLogger:Logging line number 5806
# INFO:MyLogger:Logging line number 5807
# INFO:MyLogger:Logging line number 5808
# INFO:MyLogger:Logging line number 5809
# INFO:MyLogger:Logging line number 5810
# INFO:MyLogger:Logging line number 5811
# INFO:MyLogger:Logging line number 5812
# INFO:MyLogger:Logging line number 5813
# INFO:MyLogger:Logging line number 5814
# INFO:MyLogger:Logging line number 5815
# INFO:MyLogger:Logging line number 5816
# INFO:MyLogger:Logging line number 5817
# INFO:MyLogger:Logging line number 5818
# INFO:MyLogger:Logging line number 5819
# INFO:MyLogger:Logging line number 5820
# INFO:MyLogger:Logging line number 5821
# INFO:MyLogger:Logging line number 5822
# INFO:MyLogger:Logging line number 5823
# INFO:MyLogger:Logging line number 5824
# INFO:MyLogger:Logging line number 5825
# INFO:MyLogger:Logging line number 5826
# INFO:MyLogger:Logging line number 5827
# INFO:MyLogger:Logging line number 5828
# INFO:MyLogger:Logging line number 5829
# INFO:MyLogger:Logging line number 5830
# INFO:MyLogger:Logging line number 5831
# INFO:MyLogger:Logging line number 5832
# INFO:MyLogger:Logging line number 5833
# INFO:MyLogger:Logging line number 5834
# INFO:MyLogger:Logging line number 5835
# INFO:MyLogger:Logging line number 5836
# INFO:MyLogger:Logging line number 5837
# INFO:MyLogger:Logging line number 5838
# INFO:MyLogger:Logging line number 5839
# INFO:MyLogger:Logging line number 5840
# INFO:MyLogger:Logging line number 5841
# INFO:MyLogger:Logging line number 5842
# INFO:MyLogger:Logging line number 5843
# INFO:MyLogger:Logging line number 5844
# INFO:MyLogger:Logging line number 5845
# INFO:MyLogger:Logging line number 5846
# INFO:MyLogger:Logging line number 5847
# INFO:MyLogger:Logging line number 5848
# INFO:MyLogger:Logging line number 5849
# INFO:MyLogger:Logging line number 5850
# INFO:MyLogger:Logging line number 5851
# INFO:MyLogger:Logging line number 5852
# INFO:MyLogger:Logging line number 5853
# INFO:MyLogger:Logging line number 5854
# INFO:MyLogger:Logging line number 5855
# INFO:MyLogger:Logging line number 5856
# INFO:MyLogger:Logging line number 5857
# INFO:MyLogger:Logging line number 5858
# INFO:MyLogger:Logging line number 5859
# INFO:MyLogger:Logging line number 5860
# INFO:MyLogger:Logging line number 5861
# INFO:MyLogger:Logging line number 5862
# INFO:MyLogger:Logging line number 5863
# INFO:MyLogger:Logging line number 5864
# INFO:MyLogger:Logging line number 5865
# INFO:MyLogger:Logging line number 5866
# INFO:MyLogger:Logging line number 5867
# INFO:MyLogger:Logging line number 5868
# INFO:MyLogger:Logging line number 5869
# INFO:MyLogger:Logging line number 5870
# INFO:MyLogger:Logging line number 5871
# INFO:MyLogger:Logging line number 5872
# INFO:MyLogger:Logging line number 5873
# INFO:MyLogger:Logging line number 5874
# INFO:MyLogger:Logging line number 5875
# INFO:MyLogger:Logging line number 5876
# INFO:MyLogger:Logging line number 5877
# INFO:MyLogger:Logging line number 5878
# INFO:MyLogger:Logging line number 5879
# INFO:MyLogger:Logging line number 5880
# INFO:MyLogger:Logging line number 5881
# INFO:MyLogger:Logging line number 5882
# INFO:MyLogger:Logging line number 5883
# INFO:MyLogger:Logging line number 5884
# INFO:MyLogger:Logging line number 5885
# INFO:MyLogger:Logging line number 5886
# INFO:MyLogger:Logging line number 5887
# INFO:MyLogger:Logging line number 5888
# INFO:MyLogger:Logging line number 5889
# INFO:MyLogger:Logging line number 5890
# INFO:MyLogger:Logging line number 5891
# INFO:MyLogger:Logging line number 5892
# INFO:MyLogger:Logging line number 5893
# INFO:MyLogger:Logging line number 5894
# INFO:MyLogger:Logging line number 5895
# INFO:MyLogger:Logging line number 5896
# INFO:MyLogger:Logging line number 5897
# INFO:MyLogger:Logging line number 5898
# INFO:MyLogger:Logging line number 5899
# INFO:MyLogger:Logging line number 5900
# INFO:MyLogger:Logging line number 5901
# INFO:MyLogger:Logging line number 5902
# INFO:MyLogger:Logging line number 5903
# INFO:MyLogger:Logging line number 5904
# INFO:MyLogger:Logging line number 5905
# INFO:MyLogger:Logging line number 5906
# INFO:MyLogger:Logging line number 5907
# INFO:MyLogger:Logging line number 5908
# INFO:MyLogger:Logging line number 5909
# INFO:MyLogger:Logging line number 5910
# INFO:MyLogger:Logging line number 5911
# INFO:MyLogger:Logging line number 5912
# INFO:MyLogger:Logging line number 5913
# INFO:MyLogger:Logging line number 5914
# INFO:MyLogger:Logging line number 5915
# INFO:MyLogger:Logging line number 5916
# INFO:MyLogger:Logging line number 5917
# INFO:MyLogger:Logging line number 5918
# INFO:MyLogger:Logging line number 5919
# INFO:MyLogger:Logging line number 5920
# INFO:MyLogger:Logging line number 5921
# INFO:MyLogger:Logging line number 5922
# INFO:MyLogger:Logging line number 5923
# INFO:MyLogger:Logging line number 5924
# INFO:MyLogger:Logging line number 5925
# INFO:MyLogger:Logging line number 5926
# INFO:MyLogger:Logging line number 5927
# INFO:MyLogger:Logging line number 5928
# INFO:MyLogger:Logging line number 5929
# INFO:MyLogger:Logging line number 5930
# INFO:MyLogger:Logging line number 5931
# INFO:MyLogger:Logging line number 5932
# INFO:MyLogger:Logging line number 5933
# INFO:MyLogger:Logging line number 5934
# INFO:MyLogger:Logging line number 5935
# INFO:MyLogger:Logging line number 5936
# INFO:MyLogger:Logging line number 5937
# INFO:MyLogger:Logging line number 5938
# INFO:MyLogger:Logging line number 5939
# INFO:MyLogger:Logging line number 5940
# INFO:MyLogger:Logging line number 5941
# INFO:MyLogger:Logging line number 5942
# INFO:MyLogger:Logging line number 5943
# INFO:MyLogger:Logging line number 5944
# INFO:MyLogger:Logging line number 5945
# INFO:MyLogger:Logging line number 5946
# INFO:MyLogger:Logging line number 5947
# INFO:MyLogger:Logging line number 5948
# INFO:MyLogger:Logging line number 5949
# INFO:MyLogger:Logging line number 5950
# INFO:MyLogger:Logging line number 5951
# INFO:MyLogger:Logging line number 5952
# INFO:MyLogger:Logging line number 5953
# INFO:MyLogger:Logging line number 5954
# INFO:MyLogger:Logging line number 5955
# INFO:MyLogger:Logging line number 5956
# INFO:MyLogger:Logging line number 5957
# INFO:MyLogger:Logging line number 5958
# INFO:MyLogger:Logging line number 5959
# INFO:MyLogger:Logging line number 5960
# INFO:MyLogger:Logging line number 5961
# INFO:MyLogger:Logging line number 5962
# INFO:MyLogger:Logging line number 5963
# INFO:MyLogger:Logging line number 5964
# INFO:MyLogger:Logging line number 5965
# INFO:MyLogger:Logging line number 5966
# INFO:MyLogger:Logging line number 5967
# INFO:MyLogger:Logging line number 5968
# INFO:MyLogger:Logging line number 5969
# INFO:MyLogger:Logging line number 5970
# INFO:MyLogger:Logging line number 5971
# INFO:MyLogger:Logging line number 5972
# INFO:MyLogger:Logging line number 5973
# INFO:MyLogger:Logging line number 5974
# INFO:MyLogger:Logging line number 5975
# INFO:MyLogger:Logging line number 5976
# INFO:MyLogger:Logging line number 5977
# INFO:MyLogger:Logging line number 5978
# INFO:MyLogger:Logging line number 5979
# INFO:MyLogger:Logging line number 5980
# INFO:MyLogger:Logging line number 5981
# INFO:MyLogger:Logging line number 5982
# INFO:MyLogger:Logging line number 5983
# INFO:MyLogger:Logging line number 5984
# INFO:MyLogger:Logging line number 5985
# INFO:MyLogger:Logging line number 5986
# INFO:MyLogger:Logging line number 5987
# INFO:MyLogger:Logging line number 5988
# INFO:MyLogger:Logging line number 5989
# INFO:MyLogger:Logging line number 5990
# INFO:MyLogger:Logging line number 5991
# INFO:MyLogger:Logging line number 5992
# INFO:MyLogger:Logging line number 5993
# INFO:MyLogger:Logging line number 5994
# INFO:MyLogger:Logging line number 5995
# INFO:MyLogger:Logging line number 5996
# INFO:MyLogger:Logging line number 5997
# INFO:MyLogger:Logging line number 5998
# INFO:MyLogger:Logging line number 5999
# INFO:MyLogger:Logging line number 6000
# INFO:MyLogger:Logging line number 6001
# INFO:MyLogger:Logging line number 6002
# INFO:MyLogger:Logging line number 6003
# INFO:MyLogger:Logging line number 6004
# INFO:MyLogger:Logging line number 6005
# INFO:MyLogger:Logging line number 6006
# INFO:MyLogger:Logging line number 6007
# INFO:MyLogger:Logging line number 6008
# INFO:MyLogger:Logging line number 6009
# INFO:MyLogger:Logging line number 6010
# INFO:MyLogger:Logging line number 6011
# INFO:MyLogger:Logging line number 6012
# INFO:MyLogger:Logging line number 6013
# INFO:MyLogger:Logging line number 6014
# INFO:MyLogger:Logging line number 6015
# INFO:MyLogger:Logging line number 6016
# INFO:MyLogger:Logging line number 6017
# INFO:MyLogger:Logging line number 6018
# INFO:MyLogger:Logging line number 6019
# INFO:MyLogger:Logging line number 6020
# INFO:MyLogger:Logging line number 6021
# INFO:MyLogger:Logging line number 6022
# INFO:MyLogger:Logging line number 6023
# INFO:MyLogger:Logging line number 6024
# INFO:MyLogger:Logging line number 6025
# INFO:MyLogger:Logging line number 6026
# INFO:MyLogger:Logging line number 6027
# INFO:MyLogger:Logging line number 6028
# INFO:MyLogger:Logging line number 6029
# INFO:MyLogger:Logging line number 6030
# INFO:MyLogger:Logging line number 6031
# INFO:MyLogger:Logging line number 6032
# INFO:MyLogger:Logging line number 6033
# INFO:MyLogger:Logging line number 6034
# INFO:MyLogger:Logging line number 6035
# INFO:MyLogger:Logging line number 6036
# INFO:MyLogger:Logging line number 6037
# INFO:MyLogger:Logging line number 6038
# INFO:MyLogger:Logging line number 6039
# INFO:MyLogger:Logging line number 6040
# INFO:MyLogger:Logging line number 6041
# INFO:MyLogger:Logging line number 6042
# INFO:MyLogger:Logging line number 6043
# INFO:MyLogger:Logging line number 6044
# INFO:MyLogger:Logging line number 6045
# INFO:MyLogger:Logging line number 6046
# INFO:MyLogger:Logging line number 6047
# INFO:MyLogger:Logging line number 6048
# INFO:MyLogger:Logging line number 6049
# INFO:MyLogger:Logging line number 6050
# INFO:MyLogger:Logging line number 6051
# INFO:MyLogger:Logging line number 6052
# INFO:MyLogger:Logging line number 6053
# INFO:MyLogger:Logging line number 6054
# INFO:MyLogger:Logging line number 6055
# INFO:MyLogger:Logging line number 6056
# INFO:MyLogger:Logging line number 6057
# INFO:MyLogger:Logging line number 6058
# INFO:MyLogger:Logging line number 6059
# INFO:MyLogger:Logging line number 6060
# INFO:MyLogger:Logging line number 6061
# INFO:MyLogger:Logging line number 6062
# INFO:MyLogger:Logging line number 6063
# INFO:MyLogger:Logging line number 6064
# INFO:MyLogger:Logging line number 6065
# INFO:MyLogger:Logging line number 6066
# INFO:MyLogger:Logging line number 6067
# INFO:MyLogger:Logging line number 6068
# INFO:MyLogger:Logging line number 6069
# INFO:MyLogger:Logging line number 6070
# INFO:MyLogger:Logging line number 6071
# INFO:MyLogger:Logging line number 6072
# INFO:MyLogger:Logging line number 6073
# INFO:MyLogger:Logging line number 6074
# INFO:MyLogger:Logging line number 6075
# INFO:MyLogger:Logging line number 6076
# INFO:MyLogger:Logging line number 6077
# INFO:MyLogger:Logging line number 6078
# INFO:MyLogger:Logging line number 6079
# INFO:MyLogger:Logging line number 6080
# INFO:MyLogger:Logging line number 6081
# INFO:MyLogger:Logging line number 6082
# INFO:MyLogger:Logging line number 6083
# INFO:MyLogger:Logging line number 6084
# INFO:MyLogger:Logging line number 6085
# INFO:MyLogger:Logging line number 6086
# INFO:MyLogger:Logging line number 6087
# INFO:MyLogger:Logging line number 6088
# INFO:MyLogger:Logging line number 6089
# INFO:MyLogger:Logging line number 6090
# INFO:MyLogger:Logging line number 6091
# INFO:MyLogger:Logging line number 6092
# INFO:MyLogger:Logging line number 6093
# INFO:MyLogger:Logging line number 6094
# INFO:MyLogger:Logging line number 6095
# INFO:MyLogger:Logging line number 6096
# INFO:MyLogger:Logging line number 6097
# INFO:MyLogger:Logging line number 6098
# INFO:MyLogger:Logging line number 6099
# INFO:MyLogger:Logging line number 6100
# INFO:MyLogger:Logging line number 6101
# INFO:MyLogger:Logging line number 6102
# INFO:MyLogger:Logging line number 6103
# INFO:MyLogger:Logging line number 6104
# INFO:MyLogger:Logging line number 6105
# INFO:MyLogger:Logging line number 6106
# INFO:MyLogger:Logging line number 6107
# INFO:MyLogger:Logging line number 6108
# INFO:MyLogger:Logging line number 6109
# INFO:MyLogger:Logging line number 6110
# INFO:MyLogger:Logging line number 6111
# INFO:MyLogger:Logging line number 6112
# INFO:MyLogger:Logging line number 6113
# INFO:MyLogger:Logging line number 6114
# INFO:MyLogger:Logging line number 6115
# INFO:MyLogger:Logging line number 6116
# INFO:MyLogger:Logging line number 6117
# INFO:MyLogger:Logging line number 6118
# INFO:MyLogger:Logging line number 6119
# INFO:MyLogger:Logging line number 6120
# INFO:MyLogger:Logging line number 6121
# INFO:MyLogger:Logging line number 6122
# INFO:MyLogger:Logging line number 6123
# INFO:MyLogger:Logging line number 6124
# INFO:MyLogger:Logging line number 6125
# INFO:MyLogger:Logging line number 6126
# INFO:MyLogger:Logging line number 6127
# INFO:MyLogger:Logging line number 6128
# INFO:MyLogger:Logging line number 6129
# INFO:MyLogger:Logging line number 6130
# INFO:MyLogger:Logging line number 6131
# INFO:MyLogger:Logging line number 6132
# INFO:MyLogger:Logging line number 6133
# INFO:MyLogger:Logging line number 6134
# INFO:MyLogger:Logging line number 6135
# INFO:MyLogger:Logging line number 6136
# INFO:MyLogger:Logging line number 6137
# INFO:MyLogger:Logging line number 6138
# INFO:MyLogger:Logging line number 6139
# INFO:MyLogger:Logging line number 6140
# INFO:MyLogger:Logging line number 6141
# INFO:MyLogger:Logging line number 6142
# INFO:MyLogger:Logging line number 6143
# INFO:MyLogger:Logging line number 6144
# INFO:MyLogger:Logging line number 6145
# INFO:MyLogger:Logging line number 6146
# INFO:MyLogger:Logging line number 6147
# INFO:MyLogger:Logging line number 6148
# INFO:MyLogger:Logging line number 6149
# INFO:MyLogger:Logging line number 6150
# INFO:MyLogger:Logging line number 6151
# INFO:MyLogger:Logging line number 6152
# INFO:MyLogger:Logging line number 6153
# INFO:MyLogger:Logging line number 6154
# INFO:MyLogger:Logging line number 6155
# INFO:MyLogger:Logging line number 6156
# INFO:MyLogger:Logging line number 6157
# INFO:MyLogger:Logging line number 6158
# INFO:MyLogger:Logging line number 6159
# INFO:MyLogger:Logging line number 6160
# INFO:MyLogger:Logging line number 6161
# INFO:MyLogger:Logging line number 6162
# INFO:MyLogger:Logging line number 6163
# INFO:MyLogger:Logging line number 6164
# INFO:MyLogger:Logging line number 6165
# INFO:MyLogger:Logging line number 6166
# INFO:MyLogger:Logging line number 6167
# INFO:MyLogger:Logging line number 6168
# INFO:MyLogger:Logging line number 6169
# INFO:MyLogger:Logging line number 6170
# INFO:MyLogger:Logging line number 6171
# INFO:MyLogger:Logging line number 6172
# INFO:MyLogger:Logging line number 6173
# INFO:MyLogger:Logging line number 6174
# INFO:MyLogger:Logging line number 6175
# INFO:MyLogger:Logging line number 6176
# INFO:MyLogger:Logging line number 6177
# INFO:MyLogger:Logging line number 6178
# INFO:MyLogger:Logging line number 6179
# INFO:MyLogger:Logging line number 6180
# INFO:MyLogger:Logging line number 6181
# INFO:MyLogger:Logging line number 6182
# INFO:MyLogger:Logging line number 6183
# INFO:MyLogger:Logging line number 6184
# INFO:MyLogger:Logging line number 6185
# INFO:MyLogger:Logging line number 6186
# INFO:MyLogger:Logging line number 6187
# INFO:MyLogger:Logging line number 6188
# INFO:MyLogger:Logging line number 6189
# INFO:MyLogger:Logging line number 6190
# INFO:MyLogger:Logging line number 6191
# INFO:MyLogger:Logging line number 6192
# INFO:MyLogger:Logging line number 6193
# INFO:MyLogger:Logging line number 6194
# INFO:MyLogger:Logging line number 6195
# INFO:MyLogger:Logging line number 6196
# INFO:MyLogger:Logging line number 6197
# INFO:MyLogger:Logging line number 6198
# INFO:MyLogger:Logging line number 6199
# INFO:MyLogger:Logging line number 6200
# INFO:MyLogger:Logging line number 6201
# INFO:MyLogger:Logging line number 6202
# INFO:MyLogger:Logging line number 6203
# INFO:MyLogger:Logging line number 6204
# INFO:MyLogger:Logging line number 6205
# INFO:MyLogger:Logging line number 6206
# INFO:MyLogger:Logging line number 6207
# INFO:MyLogger:Logging line number 6208
# INFO:MyLogger:Logging line number 6209
# INFO:MyLogger:Logging line number 6210
# INFO:MyLogger:Logging line number 6211
# INFO:MyLogger:Logging line number 6212
# INFO:MyLogger:Logging line number 6213
# INFO:MyLogger:Logging line number 6214
# INFO:MyLogger:Logging line number 6215
# INFO:MyLogger:Logging line number 6216
# INFO:MyLogger:Logging line number 6217
# INFO:MyLogger:Logging line number 6218
# INFO:MyLogger:Logging line number 6219
# INFO:MyLogger:Logging line number 6220
# INFO:MyLogger:Logging line number 6221
# INFO:MyLogger:Logging line number 6222
# INFO:MyLogger:Logging line number 6223
# INFO:MyLogger:Logging line number 6224
# INFO:MyLogger:Logging line number 6225
# INFO:MyLogger:Logging line number 6226
# INFO:MyLogger:Logging line number 6227
# INFO:MyLogger:Logging line number 6228
# ...
# INFO:MyLogger:Logging line number 9590
# INFO:MyLogger:Logging line number 9591
# INFO:MyLogger:Logging line number 9592
# INFO:MyLogger:Logging line number 9593
# INFO:MyLogger:Logging line number 9594
# INFO:MyLogger:Logging line number 9595
# INFO:MyLogger:Logging line number 9596
# INFO:MyLogger:Logging line number 9597
# INFO:MyLogger:Logging line number 9598
# INFO:MyLogger:Logging line number 9599
# INFO:MyLogger:Logging line number 9600
# INFO:MyLogger:Logging line number 9601
# INFO:MyLogger:Logging line number 9602
# INFO:MyLogger:Logging line number 9603
# INFO:MyLogger:Logging line number 9604
# INFO:MyLogger:Logging line number 9605
# INFO:MyLogger:Logging line number 9606
# INFO:MyLogger:Logging line number 9607
# INFO:MyLogger:Logging line number 9608
# INFO:MyLogger:Logging line number 9609
# INFO:MyLogger:Logging line number 9610
# INFO:MyLogger:Logging line number 9611
# INFO:MyLogger:Logging line number 9612
# INFO:MyLogger:Logging line number 9613
# INFO:MyLogger:Logging line number 9614
# INFO:MyLogger:Logging line number 9615
# INFO:MyLogger:Logging line number 9616
# INFO:MyLogger:Logging line number 9617
# INFO:MyLogger:Logging line number 9618
# INFO:MyLogger:Logging line number 9619
# INFO:MyLogger:Logging line number 9620
# INFO:MyLogger:Logging line number 9621
# INFO:MyLogger:Logging line number 9622
# INFO:MyLogger:Logging line number 9623
# INFO:MyLogger:Logging line number 9624
# INFO:MyLogger:Logging line number 9625
# INFO:MyLogger:Logging line number 9626
# INFO:MyLogger:Logging line number 9627
# INFO:MyLogger:Logging line number 9628
# INFO:MyLogger:Logging line number 9629
# INFO:MyLogger:Logging line number 9630
# INFO:MyLogger:Logging line number 9631
# INFO:MyLogger:Logging line number 9632
# INFO:MyLogger:Logging line number 9633
# INFO:MyLogger:Logging line number 9634
# INFO:MyLogger:Logging line number 9635
# INFO:MyLogger:Logging line number 9636
# INFO:MyLogger:Logging line number 9637
# INFO:MyLogger:Logging line number 9638
# INFO:MyLogger:Logging line number 9639
# INFO:MyLogger:Logging line number 9640
# INFO:MyLogger:Logging line number 9641
# INFO:MyLogger:Logging line number 9642
# INFO:MyLogger:Logging line number 9643
# INFO:MyLogger:Logging line number 9644
# INFO:MyLogger:Logging line number 9645
# INFO:MyLogger:Logging line number 9646
# INFO:MyLogger:Logging line number 9647
# INFO:MyLogger:Logging line number 9648
# INFO:MyLogger:Logging line number 9649
# INFO:MyLogger:Logging line number 9650
# INFO:MyLogger:Logging line number 9651
# INFO:MyLogger:Logging line number 9652
# INFO:MyLogger:Logging line number 9653
# INFO:MyLogger:Logging line number 9654
# INFO:MyLogger:Logging line number 9655
# INFO:MyLogger:Logging line number 9656
# INFO:MyLogger:Logging line number 9657
# INFO:MyLogger:Logging line number 9658
# INFO:MyLogger:Logging line number 9659
# INFO:MyLogger:Logging line number 9660
# INFO:MyLogger:Logging line number 9661
# INFO:MyLogger:Logging line number 9662
# INFO:MyLogger:Logging line number 9663
# INFO:MyLogger:Logging line number 9664
# INFO:MyLogger:Logging line number 9665
# INFO:MyLogger:Logging line number 9666
# INFO:MyLogger:Logging line number 9667
# INFO:MyLogger:Logging line number 9668
# INFO:MyLogger:Logging line number 9669
# INFO:MyLogger:Logging line number 9670
# INFO:MyLogger:Logging line number 9671
# INFO:MyLogger:Logging line number 9672
# INFO:MyLogger:Logging line number 9673
# INFO:MyLogger:Logging line number 9674
# INFO:MyLogger:Logging line number 9675
# INFO:MyLogger:Logging line number 9676
# INFO:MyLogger:Logging line number 9677
# INFO:MyLogger:Logging line number 9678
# INFO:MyLogger:Logging line number 9679
# INFO:MyLogger:Logging line number 9680
# INFO:MyLogger:Logging line number 9681
# INFO:MyLogger:Logging line number 9682
# INFO:MyLogger:Logging line number 9683
# INFO:MyLogger:Logging line number 9684
# INFO:MyLogger:Logging line number 9685
# INFO:MyLogger:Logging line number 9686
# INFO:MyLogger:Logging line number 9687
# INFO:MyLogger:Logging line number 9688
# INFO:MyLogger:Logging line number 9689
# INFO:MyLogger:Logging line number 9690
# INFO:MyLogger:Logging line number 9691
# INFO:MyLogger:Logging line number 9692
# INFO:MyLogger:Logging line number 9693
# INFO:MyLogger:Logging line number 9694
# INFO:MyLogger:Logging line number 9695
# INFO:MyLogger:Logging line number 9696
# INFO:MyLogger:Logging line number 9697
# INFO:MyLogger:Logging line number 9698
# INFO:MyLogger:Logging line number 9699
# INFO:MyLogger:Logging line number 9700
# INFO:MyLogger:Logging line number 9701
# INFO:MyLogger:Logging line number 9702
# INFO:MyLogger:Logging line number 9703
# INFO:MyLogger:Logging line number 9704
# INFO:MyLogger:Logging line number 9705
# INFO:MyLogger:Logging line number 9706
# INFO:MyLogger:Logging line number 9707
# INFO:MyLogger:Logging line number 9708
# INFO:MyLogger:Logging line number 9709
# INFO:MyLogger:Logging line number 9710
# INFO:MyLogger:Logging line number 9711
# INFO:MyLogger:Logging line number 9712
# INFO:MyLogger:Logging line number 9713
# INFO:MyLogger:Logging line number 9714
# INFO:MyLogger:Logging line number 9715
# INFO:MyLogger:Logging line number 9716
# INFO:MyLogger:Logging line number 9717
# INFO:MyLogger:Logging line number 9718
# INFO:MyLogger:Logging line number 9719
# INFO:MyLogger:Logging line number 9720
# INFO:MyLogger:Logging line number 9721
# INFO:MyLogger:Logging line number 9722
# INFO:MyLogger:Logging line number 9723
# INFO:MyLogger:Logging line number 9724
# INFO:MyLogger:Logging line number 9725
# INFO:MyLogger:Logging line number 9726
# INFO:MyLogger:Logging line number 9727
# INFO:MyLogger:Logging line number 9728
# INFO:MyLogger:Logging line number 9729
# INFO:MyLogger:Logging line number 9730
# INFO:MyLogger:Logging line number 9731
# INFO:MyLogger:Logging line number 9732
# INFO:MyLogger:Logging line number 9733
# INFO:MyLogger:Logging line number 9734
# INFO:MyLogger:Logging line number 9735
# INFO:MyLogger:Logging line number 9736
# INFO:MyLogger:Logging line number 9737
# INFO:MyLogger:Logging line number 9738
# INFO:MyLogger:Logging line number 9739
# INFO:MyLogger:Logging line number 9740
# INFO:MyLogger:Logging line number 9741
# INFO:MyLogger:Logging line number 9742
# INFO:MyLogger:Logging line number 9743
# INFO:MyLogger:Logging line number 9744
# INFO:MyLogger:Logging line number 9745
# INFO:MyLogger:Logging line number 9746
# INFO:MyLogger:Logging line number 9747
# INFO:MyLogger:Logging line number 9748
# INFO:MyLogger:Logging line number 9749
# INFO:MyLogger:Logging line number 9750
# INFO:MyLogger:Logging line number 9751
# INFO:MyLogger:Logging line number 9752
# INFO:MyLogger:Logging line number 9753
# INFO:MyLogger:Logging line number 9754
# INFO:MyLogger:Logging line number 9755
# INFO:MyLogger:Logging line number 9756
# INFO:MyLogger:Logging line number 9757
# INFO:MyLogger:Logging line number 9758
# INFO:MyLogger:Logging line number 9759
# INFO:MyLogger:Logging line number 9760
# INFO:MyLogger:Logging line number 9761
# INFO:MyLogger:Logging line number 9762
# INFO:MyLogger:Logging line number 9763
# INFO:MyLogger:Logging line number 9764
# INFO:MyLogger:Logging line number 9765
# INFO:MyLogger:Logging line number 9766
# INFO:MyLogger:Logging line number 9767
# INFO:MyLogger:Logging line number 9768
# INFO:MyLogger:Logging line number 9769
# INFO:MyLogger:Logging line number 9770
# INFO:MyLogger:Logging line number 9771
# INFO:MyLogger:Logging line number 9772
# INFO:MyLogger:Logging line number 9773
# INFO:MyLogger:Logging line number 9774
# INFO:MyLogger:Logging line number 9775
# INFO:MyLogger:Logging line number 9776
# INFO:MyLogger:Logging line number 9777
# INFO:MyLogger:Logging line number 9778
# INFO:MyLogger:Logging line number 9779
# INFO:MyLogger:Logging line number 9780
# INFO:MyLogger:Logging line number 9781
# INFO:MyLogger:Logging line number 9782
# INFO:MyLogger:Logging line number 9783
# INFO:MyLogger:Logging line number 9784
# INFO:MyLogger:Logging line number 9785
# INFO:MyLogger:Logging line number 9786
# INFO:MyLogger:Logging line number 9787
# INFO:MyLogger:Logging line number 9788
# INFO:MyLogger:Logging line number 9789
# INFO:MyLogger:Logging line number 9790
# INFO:MyLogger:Logging line number 9791
# INFO:MyLogger:Logging line number 9792
# INFO:MyLogger:Logging line number 9793
# INFO:MyLogger:Logging line number 9794
# INFO:MyLogger:Logging line number 9795
# INFO:MyLogger:Logging line number 9796
# INFO:MyLogger:Logging line number 9797
# INFO:MyLogger:Logging line number 9798
# INFO:MyLogger:Logging line number 9799
# INFO:MyLogger:Logging line number 9800
# INFO:MyLogger:Logging line number 9801
# INFO:MyLogger:Logging line number 9802
# INFO:MyLogger:Logging line number 9803
# INFO:MyLogger:Logging line number 9804
# INFO:MyLogger:Logging line number 9805
# INFO:MyLogger:Logging line number 9806
# INFO:MyLogger:Logging line number 9807
# INFO:MyLogger:Logging line number 9808
# INFO:MyLogger:Logging line number 9809
# INFO:MyLogger:Logging line number 9810
# INFO:MyLogger:Logging line number 9811
# INFO:MyLogger:Logging line number 9812
# INFO:MyLogger:Logging line number 9813
# INFO:MyLogger:Logging line number 9814
# INFO:MyLogger:Logging line number 9815
# INFO:MyLogger:Logging line number 9816
# INFO:MyLogger:Logging line number 9817
# INFO:MyLogger:Logging line number 9818
# INFO:MyLogger:Logging line number 9819
# INFO:MyLogger:Logging line number 9820
# INFO:MyLogger:Logging line number 9821
# INFO:MyLogger:Logging line number 9822
# INFO:MyLogger:Logging line number 9823
# INFO:MyLogger:Logging line number 9824
# INFO:MyLogger:Logging line number 9825
# INFO:MyLogger:Logging line number 9826
# INFO:MyLogger:Logging line number 9827
# INFO:MyLogger:Logging line number 9828
# INFO:MyLogger:Logging line number 9829
# INFO:MyLogger:Logging line number 9830
# INFO:MyLogger:Logging line number 9831
# INFO:MyLogger:Logging line number 9832
# INFO:MyLogger:Logging line number 9833
# INFO:MyLogger:Logging line number 9834
# INFO:MyLogger:Logging line number 9835
# INFO:MyLogger:Logging line number 9836
# INFO:MyLogger:Logging line number 9837
# INFO:MyLogger:Logging line number 9838
# INFO:MyLogger:Logging line number 9839
# INFO:MyLogger:Logging line number 9840
# INFO:MyLogger:Logging line number 9841
# INFO:MyLogger:Logging line number 9842
# INFO:MyLogger:Logging line number 9843
# INFO:MyLogger:Logging line number 9844
# INFO:MyLogger:Logging line number 9845
# INFO:MyLogger:Logging line number 9846
# INFO:MyLogger:Logging line number 9847
# INFO:MyLogger:Logging line number 9848
# INFO:MyLogger:Logging line number 9849
# INFO:MyLogger:Logging line number 9850
# INFO:MyLogger:Logging line number 9851
# INFO:MyLogger:Logging line number 9852
# INFO:MyLogger:Logging line number 9853
# INFO:MyLogger:Logging line number 9854
# INFO:MyLogger:Logging line number 9855
# INFO:MyLogger:Logging line number 9856
# INFO:MyLogger:Logging line number 9857
# INFO:MyLogger:Logging line number 9858
# INFO:MyLogger:Logging line number 9859
# INFO:MyLogger:Logging line number 9860
# INFO:MyLogger:Logging line number 9861
# INFO:MyLogger:Logging line number 9862
# INFO:MyLogger:Logging line number 9863
# INFO:MyLogger:Logging line number 9864
# INFO:MyLogger:Logging line number 9865
# INFO:MyLogger:Logging line number 9866
# INFO:MyLogger:Logging line number 9867
# INFO:MyLogger:Logging line number 9868
# INFO:MyLogger:Logging line number 9869
# INFO:MyLogger:Logging line number 9870
# INFO:MyLogger:Logging line number 9871
# INFO:MyLogger:Logging line number 9872
# INFO:MyLogger:Logging line number 9873
# INFO:MyLogger:Logging line number 9874
# INFO:MyLogger:Logging line number 9875
# INFO:MyLogger:Logging line number 9876
# INFO:MyLogger:Logging line number 9877
# INFO:MyLogger:Logging line number 9878
# INFO:MyLogger:Logging line number 9879
# INFO:MyLogger:Logging line number 9880
# INFO:MyLogger:Logging line number 9881
# INFO:MyLogger:Logging line number 9882
# INFO:MyLogger:Logging line number 9883
# INFO:MyLogger:Logging line number 9884
# INFO:MyLogger:Logging line number 9885
# INFO:MyLogger:Logging line number 9886
# INFO:MyLogger:Logging line number 9887
# INFO:MyLogger:Logging line number 9888
# INFO:MyLogger:Logging line number 9889
# INFO:MyLogger:Logging line number 9890
# INFO:MyLogger:Logging line number 9891
# INFO:MyLogger:Logging line number 9892
# INFO:MyLogger:Logging line number 9893
# INFO:MyLogger:Logging line number 9894
# INFO:MyLogger:Logging line number 9895
# INFO:MyLogger:Logging line number 9896
# INFO:MyLogger:Logging line number 9897
# INFO:MyLogger:Logging line number 9898
# INFO:MyLogger:Logging line number 9899
# INFO:MyLogger:Logging line number 9900
# INFO:MyLogger:Logging line number 9901
# INFO:MyLogger:Logging line number 9902
# INFO:MyLogger:Logging line number 9903
# INFO:MyLogger:Logging line number 9904
# INFO:MyLogger:Logging line number 9905
# INFO:MyLogger:Logging line number 9906
# INFO:MyLogger:Logging line number 9907
# INFO:MyLogger:Logging line number 9908
# INFO:MyLogger:Logging line number 9909
# INFO:MyLogger:Logging line number 9910
# INFO:MyLogger:Logging line number 9911
# INFO:MyLogger:Logging line number 9912
# INFO:MyLogger:Logging line number 9913
# INFO:MyLogger:Logging line number 9914
# INFO:MyLogger:Logging line number 9915
# INFO:MyLogger:Logging line number 9916
# INFO:MyLogger:Logging line number 9917
# INFO:MyLogger:Logging line number 9918
# INFO:MyLogger:Logging line number 9919
# INFO:MyLogger:Logging line number 9920
# INFO:MyLogger:Logging line number 9921
# INFO:MyLogger:Logging line number 9922
# INFO:MyLogger:Logging line number 9923
# INFO:MyLogger:Logging line number 9924
# INFO:MyLogger:Logging line number 9925
# INFO:MyLogger:Logging line number 9926
# INFO:MyLogger:Logging line number 9927
# INFO:MyLogger:Logging line number 9928
# INFO:MyLogger:Logging line number 9929
# INFO:MyLogger:Logging line number 9930
# INFO:MyLogger:Logging line number 9931
# INFO:MyLogger:Logging line number 9932
# INFO:MyLogger:Logging line number 9933
# INFO:MyLogger:Logging line number 9934
# INFO:MyLogger:Logging line number 9935
# INFO:MyLogger:Logging line number 9936
# INFO:MyLogger:Logging line number 9937
# INFO:MyLogger:Logging line number 9938
# INFO:MyLogger:Logging line number 9939
# INFO:MyLogger:Logging line number 9940
# INFO:MyLogger:Logging line number 9941
# INFO:MyLogger:Logging line number 9942
# INFO:MyLogger:Logging line number 9943
# INFO:MyLogger:Logging line number 9944
# INFO:MyLogger:Logging line number 9945
# INFO:MyLogger:Logging line number 9946
# INFO:MyLogger:Logging line number 9947
# INFO:MyLogger:Logging line number 9948
# INFO:MyLogger:Logging line number 9949
# INFO:MyLogger:Logging line number 9950
# INFO:MyLogger:Logging line number 9951
# INFO:MyLogger:Logging line number 9952
# INFO:MyLogger:Logging line number 9953
# INFO:MyLogger:Logging line number 9954
# INFO:MyLogger:Logging line number 9955
# INFO:MyLogger:Logging line number 9956
# INFO:MyLogger:Logging line number 9957
# INFO:MyLogger:Logging line number 9958
# INFO:MyLogger:Logging line number 9959
# INFO:MyLogger:Logging line number 9960
# INFO:MyLogger:Logging line number 9961
# INFO:MyLogger:Logging line number 9962
# INFO:MyLogger:Logging line number 9963
# INFO:MyLogger:Logging line number 9964
# INFO:MyLogger:Logging line number 9965
# INFO:MyLogger:Logging line number 9966
# INFO:MyLogger:Logging line number 9967
# INFO:MyLogger:Logging line number 9968
# INFO:MyLogger:Logging line number 9969
# INFO:MyLogger:Logging line number 9970
# INFO:MyLogger:Logging line number 9971
# INFO:MyLogger:Logging line number 9972
# INFO:MyLogger:Logging line number 9973
# INFO:MyLogger:Logging line number 9974
# INFO:MyLogger:Logging line number 9975
# INFO:MyLogger:Logging line number 9976
# INFO:MyLogger:Logging line number 9977
# INFO:MyLogger:Logging line number 9978
# INFO:MyLogger:Logging line number 9979
# INFO:MyLogger:Logging line number 9980
# INFO:MyLogger:Logging line number 9981
# INFO:MyLogger:Logging line number 9982
# INFO:MyLogger:Logging line number 9983
# INFO:MyLogger:Logging line number 9984
# INFO:MyLogger:Logging line number 9985
# INFO:MyLogger:Logging line number 9986
# INFO:MyLogger:Logging line number 9987
# INFO:MyLogger:Logging line number 9988
# INFO:MyLogger:Logging line number 9989
# INFO:MyLogger:Logging line number 9990
# INFO:MyLogger:Logging line number 9991
# INFO:MyLogger:Logging line number 9992
# INFO:MyLogger:Logging line number 9993
# INFO:MyLogger:Logging line number 9994
# INFO:MyLogger:Logging line number 9995
# INFO:MyLogger:Logging line number 9996
# INFO:MyLogger:Logging line number 9997
# INFO:MyLogger:Logging line number 9998
# INFO:MyLogger:Logging line number 9999

# %% [markdown]
# 19. Write a program that handles both IndexError and KeyError using a try-except block.

# %%
my_list = [10, 20, 30]
my_dict = {"name": "Gandhi", "age": 25}

try:
    # Trying to access invalid index and missing key
    print("List item:", my_list[5])
    print("City:", my_dict["city"])

except IndexError:
    print("Error: List index is out of range.")

except KeyError:
    print("Error: Key not found in dictionary.")
# Out:
# Error: List index is out of range.

# %% [markdown]
# 20. How would you open a file and read its contents using a context manager in Python.

# %%
with open("example.txt", "r") as file:
    content = file.read()
    print(content)

# %% [markdown]
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

# %%
import re

# Create the file with sample content
with open("example.txt", "w") as file:
    file.write("Data is powerful. Data drives decisions. Big data is the future.")

# Now read and count occurrences of the word
word_to_find = "data"

with open("example.txt", "r") as file:
    content = file.read()

words = re.findall(r'\b' + re.escape(word_to_find) + r'\b', content, flags=re.IGNORECASE)
count = len(words)

print(f"The word '{word_to_find}' occurred {count} times.")
# Out:
# The word 'data' occurred 3 times.

# %% [markdown]
# 22. How can you check if a file is empty before attempting to read its contents?

# %%
import os

file_path = "example.txt"

if os.path.exists(file_path) and os.path.getsize(file_path) > 0:
    with open(file_path, "r") as file:
        content = file.read()
        print("File content:")
        print(content)
else:
    print("The file is either empty or does not exist.")
# Out:
# File content:
# Data is powerful. Data drives decisions. Big data is the future.

# %% [markdown]
# 23. Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging

# Set up logging
logging.basicConfig(filename='file_errors.log', level=logging.ERROR, format='%(asctime)s - %(levelname)s - %(message)s')

try:
    with open("nonexistent_file.txt", "r") as file:
        content = file.read()
        print(content)

except FileNotFoundError as e:
    logging.error("File not found error: %s", e)
    print("An error occurred. Check 'file_errors.log' for details.")
# Out:
# ERROR:root:File not found error: [Errno 2] No such file or directory: 'nonexistent_file.txt'
# An error occurred. Check 'file_errors.log' for details.
